# %% [markdown]
# # Heading1

# %% [markdown]
# ## Heading2

# %% [markdown]
# ### Heading3

# %% [markdown]
# #### Heading4

# %% [markdown]
# ##### Heading5

# %% [markdown]
# ###### Heading6

# %% [markdown]
# # *Hii*

# %% [markdown]
# # **Hii**

# %% [markdown]
# ---

# %% [markdown]
# |name|course|
# |varshine|DS|

# %% [markdown]
# |name|course|
# |---|---|
# |varshine|ai&ds|

# %% [markdown]
# 1. C
# 2. C++

# %% [markdown]
# **Varshine**

# %% [markdown]
# ~~~
# print
# ("Hello")
# ~~~

# %% [markdown]
# - Hello
# - Hii
# - Welcome

# %%
Insert
